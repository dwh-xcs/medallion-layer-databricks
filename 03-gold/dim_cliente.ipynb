# %% [markdown]
# ## 00. dim_cliente
#
# - PK:
#   - `sk_cliente`
#
# - Sequence By:
#   - `order_date`
#
# - Descrição:
#   - Dados tratados e padronizados, com tipos corrigidos, campos calculados e registros inválidos filtrados.
#
# - Objetivo:
#   - Limpezas e enriquecimentos:
#     - Converter tipos (`quantity` → int, `unit_price` → float).
#     - Normalizar `country` e `status`.
#     - Criar campo `total_price = quantity * unit_price`.
#
# Autor: David Costa
