# %% [markdown]
# #### 🧍 Dim_Cliente
#
# - PK:
#   - `sk_cliente`
#
# - Sequence By:
#   - `ts_load`
#
# - Descrição:
#   - tabela Dim_Cliente é uma dimensão que centraliza as informações cadastrais de todos os clientes da organização.
#
# - Objetivo:
#   | Campo       | Tipo   |
#   | ----------- | ------ |
#   | cd_cliente  | INT    |
#   | id_cliente  | STRING |
#
# Autor: David Costa

# %% [markdown]
# ## 01. Descrições/Parâmetros

# %%
# Definições de parâmetros e Descrição.
dicionario = {
    ## Destino.
    "catalog": "lakeflow",
    "schema": "c_silver",
    "prefix": "dim",
    "table": "cliente",
    ## Origem.
    "orCatalog": "lakeflow",
    "orSchema": "c_silver",
    "orTable": "slv_orders",
    # Informações.
    "PK": "cd_cliente",
    "partition": "dt_partition",
    "sequence_by": "ts_load",
    "Descrição": "Tabela Dim_Cliente é uma dimensão que centraliza as informações cadastrais de todos os clientes da organização."
}

# Cria o caminho de origem dos arquivos.
orPath = f'{dicionario["orCatalog"]}.{dicionario["orSchema"]}.{dicionario["orTable"]}'
print(f"Caminho de origem (Bronze): {orPath}")

# Cria o caminho de destino dos arquivos.
path = f'{dicionario["catalog"]}.{dicionario["schema"]}.{dicionario["prefix"]}_{dicionario["table"]}'
print(f"Caminho de destino (Silver): {path}")

# %%
# Definições de parâmetros e Descrição.
orders_schema_dict = {
    "cd_cliente": {
        "datatype": "integer",
        "description": "Código único do cliente."
    },          
    "id_cliente": {
        "datatype": "string",
        "description": ""
    },
    "ts_load": {
        "datatype": "Timestamp",
        "description": "Data e hora de ingestão do registro no Data Lake."
    }
}

# %%
# %sql
SELECT * FROM lakeflow.c_silver.slv_orders
